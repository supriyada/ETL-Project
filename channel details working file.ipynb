# %%
import pandas as pd
import os

# %%
channel_details_file=os.path.join('Resources','Raw Data','Channel_data.csv')

print(channel_details_file)
# Out:
# Resources\Raw Data\Channel_data.csv

# %%
channel_details_raw_df = pd.read_csv(channel_details_file)
channel_details_raw_df.head()
# Out:
#    totalviews_channelelapsedtime                 channelid  videocategoryid  \
# 0                       0.165199  UCdzU3DSGzyWzN2118yd9X9g               22
# 1                       1.133820  UC0UnhAG47DRyVZGVcbhAXhQ               10
# 2                       0.668120  UCXjtAvK5P3wXBGh0vbGylzg               27
# 3                      25.653505  UCeKHMeUlcLNPLCLUfZUQI2w               26
# 4                      52.773778  UCNWPDyaWf2eAHnofFLSnEMg               20
#
#    channelviewcount  likes_subscriber  views_subscribers  videocount  \
# 0             14654          0.555556          95.111111          30
# 1            105909          0.239130          59.326087          51
# 2             48265          0.023669          10.289941          72
# 3           2116722          0.007301           0.884178         172
# 4           1649075          0.004545          10.004545        2777
#
#    subscribercount      videoid  dislikes_views  ...  comments_views  \
# ...

# %%
channel_details_df = channel_details_raw_df[['channelid','videocategoryid','channelviewcount','videocount','subscribercount']]
channel_details_df
# Out:
#                     channelid  videocategoryid  channelviewcount  videocount  \
# 0    UCdzU3DSGzyWzN2118yd9X9g               22             14654          30
# 1    UC0UnhAG47DRyVZGVcbhAXhQ               10            105909          51
# 2    UCXjtAvK5P3wXBGh0vbGylzg               27             48265          72
# 3    UCeKHMeUlcLNPLCLUfZUQI2w               26           2116722         172
# 4    UCNWPDyaWf2eAHnofFLSnEMg               20           1649075        2777
# ..                        ...              ...               ...         ...
# 995  UC2l2CRfsl73FV5EETuNcNhg               10             23572          81
# 996  UCjaSeKdnPGviZREF6EcnJcw               24            390440          35
# 997  UCD-9G8Ryrq9o7M3fEWk5rsA               22              2521           1
# 998  UCXbBAdHOCyfUd6ruv_RUOPQ               20             86773         198
# 999  UCKm_mjfGRx0kCT7QKNiuylw               20           5839602         165
#
#      subscribercount
# 0                 18
# ...
