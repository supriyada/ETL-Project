# %%
#def top_youtuber():
import pandas as pd

import requests
from splinter import Browser
from bs4 import BeautifulSoup as bs
import urllib.request  as urllib2 
import time

from webdriver_manager.chrome import ChromeDriverManager








#return user_Details_df

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

url = "https://www.noxinfluencer.com/youtube-channel-rank/top-100-all-all-youtuber-sorted-by-subs-weekly"
browser.visit(url)
headline_html = browser.html
soup = bs(headline_html, "html.parser")

# %%
user_df = pd.DataFrame({'Channel_id':[],
                            'Channel_title':[],
                            'Category_name':[]})
try:
    table_data = soup.findAll('tr', attrs={'class':'item'})
    for data in table_data:
        id = data.find('a')['href']
        name = data.find('span', {'class':"name kol-name"}).text
        category = data.find('a',{'class':"category-text"}).text
        print(id )
        print(name)
        print(category)
        
        user_df = user_df.append({'Channel_id':id,
                                'Channel_title':name,
                                'Category_name':category},ignore_index = True)
        
                
except:
    print(error)
    
user_df

# %%
browser.quit()

# %%
user_df

# %%
def top_youtuber():
    from selenium import webdriver
    from bs4 import BeautifulSoup as soup
    import time
    import os
    driver = webdriver.Chrome(ChromeDriverManager().install())
    driver.get('https://www.noxinfluencer.com/youtube-channel-rank/top-100-all-all-youtuber-sorted-by-subs-weekly')
    last_height = driver.execute_script("return document.body.scrollHeight")
    while True:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(0.5)
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height

    user_df = pd.DataFrame({'Channel_id':[],
                                'Channel_title':[],
                                'Category_name':[]})
    try:
        table_data = soup(driver.page_source,'html.parser').findAll('tr', attrs={'class':'item'})
        for data in table_data:
            id = data.find('a')['href']
            name = data.find('span', {'class':"name kol-name"}).text
            category = data.find('a',{'class':"category-text"}).text

            user_df = user_df.append({'Channel_id':id,
                                    'Channel_title':name,
                                    'Category_name':category},ignore_index = True)      

    except:
        print(error)

    driver.quit()

    #user_df[['empty','youtube','channel','Channel_id']] = user_df['Channel_id'].str.split('/',expand=True)

    #user_info_df = user_df.drop(['empty', 'youtube','channel'], axis = 1)

    return user_df

# %%
top_youtuber()
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 90.0.4430
# [WDM] - Get LATEST driver version for 90.0.4430
# [WDM] - Driver [C:\Users\jegan\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
#                                    Channel_id  \
# 0   /youtube/channel/UCq-Fj5jknLsUf-MWSy4_brA
# 1   /youtube/channel/UCbCmjCuTUZos6Inko4u57UQ
# 2   /youtube/channel/UC-lHJZR3Gqxm24_Vd_AJ5Yw
# 3   /youtube/channel/UCpEhnqL0y41EpW2TvWAHD7Q
# 4   /youtube/channel/UCk8GzjMOrta8yxDcKfylJYw
# ..                                        ...
# 95  /youtube/channel/UClZF7OsrECe3t_ADrjZEh_Q
# 96  /youtube/channel/UCbrd1vu4_7qIE6IPV_dA-OA
# 97  /youtube/channel/UCtW7qWjpCZ8zps-Cf2NF26w
# 98  /youtube/channel/UCLsooMJoIpl_7ux2jvdPB-Q
# 99  /youtube/channel/UCAvCL8hyXjSUHKEGuUPr1BA
#
#                        Channel_title       Category_name
# 0                           T-Series              Music
# 1         Cocomelon - Nursery Rhymes          Education
# 2                          PewDiePie             Gaming
# 3                          SET India      Entertainment
# 4                  ✿ Kids Diana Show   Film & Animation
# ..                               ...                 ...
# 95                          Geet MP3              Music
# 96                            GENIAL      Howto & Style
# 97                 Gaane Sune Ansune              Music
# 98   Super Simple Songs - Kids Songs          Education
# 99                      Shawn Mendes      Entertainment
#
# [100 rows x 3 columns]

# %%
user_df

user_df.to_csv("log.csv")

# %%
user_df[['empty','youtube','channel','Channel_id']] = user_df['Channel_id'].str.split('/',expand=True)

user_info_df = user_df.drop(['empty', 'youtube','channel'], axis = 1)
user_info_df
